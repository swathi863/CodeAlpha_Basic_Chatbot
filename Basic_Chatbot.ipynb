# %% [markdown]
# <a href="https://colab.research.google.com/github/swathi863/CodeAlpha_Basic_Chatbot/blob/main/Basic_Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required libraries
# !pip install nltk

# Import modules
import nltk
import random
import string
nltk.download('punkt')
nltk.download('punkt_tab')

nltk.download('wordnet')

from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# Define chatbot corpus (you can expand this)
corpus = {
    "greetings": ["hello", "hi", "hey", "greetings", "what's up"],
    "goodbye": ["bye", "goodbye", "see you", "take care"],
    "thanks": ["thanks", "thank you"],
    "help": ["help", "assist", "support"],
    "weather": ["weather", "rain", "sunny", "forecast"],
}

responses = {
    "greetings": ["Hi there!", "Hello!", "Hey!", "Hi, how can I help you?"],
    "goodbye": ["Goodbye!", "See you later!", "Take care!"],
    "thanks": ["You're welcome!", "Glad to help!", "Any time!"],
    "help": ["I can assist with weather, greetings, and simple replies."],
    "weather": ["It's sunny today!", "Expect rain tomorrow.", "Cloudy with a chance of meatballs!"],
    "default": ["Sorry, I didn’t understand that.", "Can you rephrase?", "Hmm... I'm still learning."]
}

# Preprocess user input
def preprocess(text):
    text = text.lower().translate(str.maketrans('', '', string.punctuation))
    tokens = word_tokenize(text)
    return [lemmatizer.lemmatize(word) for word in tokens]

# Generate response
def generate_response(user_input):
    tokens = preprocess(user_input)
    for category, keywords in corpus.items():
        if any(word in tokens for word in keywords):
            return random.choice(responses[category])
    return random.choice(responses["default"])

# Chat loop
print("🤖 Chatbot: Hi! I'm a simple bot. Type 'bye' to exit.")
while True:
    user_input = input("You: ")
    if "bye" in user_input.lower():
        print("🤖 Chatbot:", random.choice(responses["goodbye"]))
        break
    response = generate_response(user_input)
    print("🤖 Chatbot:", response)
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 🤖 Chatbot: Hi! I'm a simple bot. Type 'bye' to exit.
# You: hello
# 🤖 Chatbot: Hi, how can I help you?
# You: can you help me?
# 🤖 Chatbot: I can assist with weather, greetings, and simple replies.
# You: what's weather like?
# 🤖 Chatbot: Cloudy with a chance of meatballs!
# You: thanks
# 🤖 Chatbot: Glad to help!
# You: see you later
# 🤖 Chatbot: Hmm... I'm still learning.
# You: what is weather condition
# 🤖 Chatbot: Expect rain tomorrow.
# You: goodbye
# 🤖 Chatbot: Take care!
